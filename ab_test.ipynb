# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import scipy.stats as st

# %%
df=pd.read_csv(r"C:\Users\arv20\Desktop\5th sem\FDS\top50.csv",encoding='latin1')
df
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
df = df.drop(columns = ['Unnamed: 0'])

# %%
df.describe()
# Out:
#        Beats.Per.Minute     Energy  Danceability  Loudness..dB..   Liveness  \
# count         50.000000  50.000000      50.00000       50.000000  50.000000
# mean         120.060000  64.060000      71.38000       -5.660000  14.660000
# std           30.898392  14.231913      11.92988        2.056448  11.118306
# min           85.000000  32.000000      29.00000      -11.000000   5.000000
# 25%           96.000000  55.250000      67.00000       -6.750000   8.000000
# 50%          104.500000  66.500000      73.50000       -6.000000  11.000000
# 75%          137.500000  74.750000      79.75000       -4.000000  15.750000
# max          190.000000  88.000000      90.00000       -2.000000  58.000000
#
#         Valence.     Length.  Acousticness..  Speechiness.  Popularity
# count  50.000000   50.000000       50.000000     50.000000   50.000000
# mean   54.600000  200.960000       22.160000     12.480000   87.500000
# std    22.336024   39.143879       18.995553     11.161596    4.491489
# ...

# %% [markdown]
# h0: the mean beats per minute of a song in 2019 is 120
# h1: the mean beats per minute of a song in 2019 is not equal to 120

# %%
alpha=0.025
y = df['Beats.Per.Minute'].astype(int)
y.mean()    #population mean
# Out:
# 120.06

# %%
n=40   #sample size
for i in range(100):
    mu=y.sample(n=40).mean()    #sample mean
    print(mu)
# Out:
# 116.775
# 119.375
# 122.125
# 123.95
# 121.125
# 120.15
# 118.525
# 118.925
# 119.15
# 118.2
# 120.25
# 117.075
# 121.95
# 121.9
# 121.025
# 120.25
# 121.075
# 120.025
# 121.6
# 119.35
# 118.225
# 120.125
# 121.525
# 115.925
# 120.775
# 117.85
# 121.375
# 121.0
# 121.175
# 118.4
# 121.725
# 120.675
# 117.7
# 121.175
# 120.2
# 122.4
# 119.15
# 120.025
# 120.025
# 120.2
# 117.4
# 120.8
# 117.675
# 120.15
# 121.0
# 117.45
# 113.1
# 122.425
# 117.675
# 119.65
# 119.2
# 117.75
# 124.225
# 119.8
# 120.725
# 118.025
# 123.65
# 120.95
# 115.475
# 117.075
# 122.325
# 118.1
# 119.375
# 119.175
# 122.325
# 118.225
# 118.375
# 118.875
# 118.875
# 123.45
# 121.425
# 119.3
# 120.45
# 119.225
# 119.025
# 122.375
# 123.9
# 123.175
# 121.475
# 117.125
# 118.075
# 118.525
# 114.2
# 118.85
# 118.475
# 117.425
# 121.325
# 120.15
# 118.675
# 119.5
# 120.975
# 121.55
# 118.25
# 120.35
# 121.025
# 120.15
# 124.25
# 119.975
# 117.875
# 117.6

# %%
s=y.std()
s                  #standad deviation
# Out:
# 30.898391742045384

# %%
z=(y-mu)/(s/np.sqrt(n))
z.mean()
# Out:
# -0.16170416715466415

# %%
z_critical = abs(st.norm.ppf(alpha))
z_critical
# Out:
# 1.9599639845400545

# %%
y.hist()
plt.scatter(120, 0, color='red', s=30)

# %%
#the upper critical value is 
ucv=120+1.96*30
#lower critical value
lcv=120-1.96*30
print(ucv)
print(lcv)
# Out:
# 178.8
# 61.2

# %%
the mean value always stays in the range

# %%
since its tow tailed test the calculated z value and the critical z value which is in range of +1.96 - -1.96 and never crosses the range 
therefore we support the null hypothesis 
average beat of a music in 2019 in a spotify dataset is 120

# %%
t - test

# %%
n = 10
degrees_of_freedom = n-1
xbar = 120
alpha = 0.05

# %%
m=y.sample(n=10).mean()
print(m)
stnd=y.std()
print(stnd)
# Out:
# 116.6
# 30.898391742045384

# %%
t = (xbar - m)/(stnd/ np.sqrt(n))
t
# Out:
# 0.3479709926113059

# %%
t_critical = st.t.ppf(alpha/2, degrees_of_freedom)
t_critical
# Out:
# -2.262157162740992

# %%
if (abs(t) > abs(t_critical)): #Absolute value taken as the it's a two-tailed test and the original t_critical value might be negative
    print("Reject null hypothesis") 
else:
    print("Null hypothesis cannot be rejected")
# Out:
# Null hypothesis cannot be rejected

# %%
even using t test it ahowed that we have to support the null hypothesis which is to accept the null hypothesis
therefore the average beats per music is 120
